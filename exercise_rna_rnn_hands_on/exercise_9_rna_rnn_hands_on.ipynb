# %% [markdown]
# # Overview
# For this exercise, we will be implementing an LSTM, a popular variant of an RNN, and training it on DMS unpaired probabilities for RNA sequences and using this to enhance the predictive performance of RNAfold in RNA secondary structure prediction. Vienna RNAfold can be used either by the webserver interface or can be installed and used locally. The workflow to solve this task will be organized as follows:
#
# 1. [Install packages and download data](#install-packages-and-download-data)
# 2. [Preprocess DMS data](#dataset-preprocessing)
# 3. [Define LSTM](#lstm-architecture)
# 4. [Weisfeiler Lehman algorithm](#weisfeiler-lehman-algorithm)
# 5. [RNAfold local implementation](#rnafold-local-implementation)
# 6. [LSTM training and evaluation](#lstm-training-and-evaluation)

# %% [markdown]
# # Install packages and download data
# Before starting, ensure the following libraries are installed along with Python 3.6+

# %%
# %pip install numpy pandas scikit-learn biopython torch torchvision torch-geometric
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/koeksalr/.local/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/koeksalr/.local/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: scikit-learn in /home/koeksalr/.local/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: biopython in /home/koeksalr/.local/lib/python3.10/site-packages (1.84)
# Requirement already satisfied: torch in /home/koeksalr/.local/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: torchvision in /home/koeksalr/.local/lib/python3.10/site-packages (0.20.1)
# Requirement already satisfied: torch-geometric in /home/koeksalr/.local/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/koeksalr/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /home/koeksalr/.local/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/koeksalr/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: filelock in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: jinja2 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: triton==3.1.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: networkx in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (3.4.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: fsspec in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /home/koeksalr/.local/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision) (9.0.1)
# Requirement already satisfied: tqdm in /home/koeksalr/.local/lib/python3.10/site-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohttp in /home/koeksalr/.local/lib/python3.10/site-packages (from torch-geometric) (3.11.11)
# Requirement already satisfied: pyparsing in /usr/lib/python3/dist-packages (from torch-geometric) (2.4.7)
# Requirement already satisfied: requests in /home/koeksalr/.local/lib/python3.10/site-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: psutil>=5.8.0 in /usr/lib/python3/dist-packages (from torch-geometric) (5.9.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (24.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (2.4.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from aiohttp->torch-geometric) (0.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/koeksalr/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->torch-geometric) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->torch-geometric) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/koeksalr/.local/lib/python3.10/site-packages (from requests->torch-geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->torch-geometric) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Download the DMS dataset if you have not already done so from: https://github.com/BackofenLab/ML_LS_resources/blob/master/exercise_9_rna_rnn_hands_on/dms_dataset.fa

# %% [markdown]
# In this workflow, we will be using an LSTM trained on DMS feature vectors of RNA structures to predict the likelihood of nucleotides being unpaired ie. accessible and not involved in base pairing for the RNA's corresponding secondary structure. We will then use these predicted DMS feature vectors to enhance the predictions of Vienna RNAfold, a thermodynamic model for RNA secondary structure prediction.
#
# For this exercise, you may use RNAfold via either the web browser interface or by downloading, installing, and implementing it locally.

# %% [markdown]
# The Vienna RNAfold webserver may be accessed in a web browser via: http://rna.tbi.univie.ac.at//cgi-bin/RNAWebSuite/RNAfold.cgi

# %% [markdown]
# To download and install RNAfold locally, we will compile it from the source code.
#
# First download the source code (.tar.gz file) into your working directory then follow the instructions below to unpack, configure, and make the package directly from source.
#
# Download the source code for your operating system from: https://www.tbi.univie.ac.at/RNA/index.html#download

# %%
# Run this to install from the source code in the directory of the downloaded .tar.gz file
# !tar -zxvf ViennaRNA-2.7.0.tar.gz
# !cd ViennaRNA-2.7.0
# !./configure
# !make
# !sudo make install
# Out:
# ViennaRNA-2.7.0/
# ViennaRNA-2.7.0/license.txt
# ViennaRNA-2.7.0/configure.ac
# ViennaRNA-2.7.0/RNAlib2.pc.in
# ViennaRNA-2.7.0/compile
# ViennaRNA-2.7.0/NEWS
# ViennaRNA-2.7.0/Makefile.in
# ViennaRNA-2.7.0/packaging/
# ViennaRNA-2.7.0/packaging/win_installer_archlinux_x86_64.nsi.in
# ViennaRNA-2.7.0/packaging/viennarna.spec.in
# ViennaRNA-2.7.0/packaging/macosx/
# ViennaRNA-2.7.0/packaging/macosx/resources/
# ViennaRNA-2.7.0/packaging/macosx/resources/welcome.txt.in
# ViennaRNA-2.7.0/packaging/macosx/resources/welcome.txt
# ViennaRNA-2.7.0/packaging/macosx/resources/conclusion.html
# ViennaRNA-2.7.0/packaging/macosx/resources/ohm.png
# ViennaRNA-2.7.0/packaging/macosx/Makefile.in
# ViennaRNA-2.7.0/packaging/macosx/Makefile.am
# ViennaRNA-2.7.0/packaging/macosx/Distribution.xml.in
# ViennaRNA-2.7.0/packaging/macosx/uninstall-ViennaRNA-Package.sh
# ViennaRNA-2.7.0/packaging/win_installer_fedora_i686.nsi.in
# ViennaRNA-2.7.0/packaging/debian/
# ViennaRNA-2.7.0/packaging/debian/perl-rna.install.in
# ViennaRNA-2.7.0/packaging/debian/viennarna-dev.install
# ViennaRNA-2.7.0/packaging/debian/control
# ViennaRNA-2.7.0/packaging/debian/viennarna-doc.install
# ViennaRNA-2.7.0/packaging/debian/python3-rna.install.in
# ViennaRNA-2.7.0/packaging/debian/changelog
# ViennaRNA-2.7.0/packaging/debian/rules
# ViennaRNA-2.7.0/packaging/debian/source.lintian-overrides
# ViennaRNA-2.7.0/packaging/debian/compat
# ViennaRNA-2.7.0/packaging/debian/copyright
# ViennaRNA-2.7.0/packaging/debian/viennarna.install
# ViennaRNA-2.7.0/packaging/PKGBUILD.in
# ViennaRNA-2.7.0/packaging/make_windows_installer.sh
# ViennaRNA-2.7.0/packaging/win_installer_archlinux_i686.nsi.in
# ViennaRNA-2.7.0/packaging/win_installer_fedora_x86_64.nsi.in
# ViennaRNA-2.7.0/configure
# ViennaRNA-2.7.0/silent_rules.mk
# ViennaRNA-2.7.0/man/
# ViennaRNA-2.7.0/man/RNAsubopt.1
# ViennaRNA-2.7.0/man/RNAdos.1
# ViennaRNA-2.7.0/man/RNApvmin.1
# ViennaRNA-2.7.0/man/RNAsnoop.1
# ViennaRNA-2.7.0/man/RNAfold.1
# ViennaRNA-2.7.0/man/Makefile.in
# ViennaRNA-2.7.0/man/RNA2Dfold.1
# ViennaRNA-2.7.0/man/include/
# ViennaRNA-2.7.0/man/include/RNAduplex.inc
# ViennaRNA-2.7.0/man/include/RNAsubopt.inc
# ViennaRNA-2.7.0/man/include/RNApdist.inc
# ViennaRNA-2.7.0/man/include/RNAaliduplex.inc
# ViennaRNA-2.7.0/man/include/RNAdistance.inc
# ViennaRNA-2.7.0/man/include/RNAplfold.inc
# ViennaRNA-2.7.0/man/include/RNALfold.inc
# ViennaRNA-2.7.0/man/include/RNAheat.inc
# ViennaRNA-2.7.0/man/include/RNAeval.inc
# ViennaRNA-2.7.0/man/include/RNA2Dfold.inc
# ViennaRNA-2.7.0/man/include/RNAplot.inc
# ViennaRNA-2.7.0/man/include/RNAfold.inc
# ViennaRNA-2.7.0/man/include/ref_package.inc
# ViennaRNA-2.7.0/man/include/ref_energy_par.inc
# ViennaRNA-2.7.0/man/include/RNAinverse.inc
# ViennaRNA-2.7.0/man/include/RNAparconv.inc
# ViennaRNA-2.7.0/man/include/RNAplex.inc
# ViennaRNA-2.7.0/man/include/RNAPKplex.inc
# ViennaRNA-2.7.0/man/include/RNALalifold.inc
# ViennaRNA-2.7.0/man/include/RNAdos.inc
# ViennaRNA-2.7.0/man/include/RNAup.inc
# ViennaRNA-2.7.0/man/include/RNApvmin.inc
# ViennaRNA-2.7.0/man/include/RNAsnoop.inc
# ViennaRNA-2.7.0/man/include/RNAcofold.inc
# ViennaRNA-2.7.0/man/include/RNAalifold.inc
# ViennaRNA-2.7.0/man/include/RNApaln.inc
# ViennaRNA-2.7.0/man/RNApaln.1
# ViennaRNA-2.7.0/man/RNAinverse.1
# ViennaRNA-2.7.0/man/RNAmultifold.1
# ViennaRNA-2.7.0/man/RNALalifold.1
# ViennaRNA-2.7.0/man/RNAplfold.1
# ViennaRNA-2.7.0/man/cmdlopt.sh.in
# ViennaRNA-2.7.0/man/RNAlib.texi
# ViennaRNA-2.7.0/man/RNAlib.info
# ViennaRNA-2.7.0/man/RNAPKplex.1
# ViennaRNA-2.7.0/man/RNAalifold.1
# ViennaRNA-2.7.0/man/texinfo.tex
# ViennaRNA-2.7.0/man/RNAplot.1
# ViennaRNA-2.7.0/man/RNAaliduplex.1
# ViennaRNA-2.7.0/man/ct2db.1
# ViennaRNA-2.7.0/man/RNAparconv.1
# ViennaRNA-2.7.0/man/Makefile.am
# ViennaRNA-2.7.0/man/RNAdistance.1
# ViennaRNA-2.7.0/man/RNAeval.1
# ViennaRNA-2.7.0/man/RNAheat.1
# ViennaRNA-2.7.0/man/RNAplex.1
# ViennaRNA-2.7.0/man/RNAduplex.1
# ViennaRNA-2.7.0/man/RNAup.1
# ViennaRNA-2.7.0/man/RNALfold.1
# ViennaRNA-2.7.0/man/RNApdist.1
# ViennaRNA-2.7.0/man/RNAcofold.1
# ViennaRNA-2.7.0/config.h.in
# ViennaRNA-2.7.0/aclocal.m4
# ViennaRNA-2.7.0/misc/
# ViennaRNA-2.7.0/misc/2Dlandscape_pf.gri
# ViennaRNA-2.7.0/misc/rna_mod_template_parameters.json
# ViennaRNA-2.7.0/misc/2Dlandscape_mfe.gri
# ViennaRNA-2.7.0/misc/Makefile.in
# ViennaRNA-2.7.0/misc/rna_andronescu2007.par
# ViennaRNA-2.7.0/misc/dna_mathews1999.par
# ViennaRNA-2.7.0/misc/dna_mathews2004.par
# ViennaRNA-2.7.0/misc/2Dlandscape.R
# ViennaRNA-2.7.0/misc/rna_mod_dihydrouridine_parameters.json
# ViennaRNA-2.7.0/misc/rna_mod_inosine_parameters.json
# ViennaRNA-2.7.0/misc/rna_misc_special_hairpins.par
# ViennaRNA-2.7.0/misc/rna_mod_7DA_parameters.json
# ViennaRNA-2.7.0/misc/parameter_files.txt
# ViennaRNA-2.7.0/misc/rna_langdon2018.par
# ViennaRNA-2.7.0/misc/rna_mod_pseudouridine_parameters.json
# ViennaRNA-2.7.0/misc/Makefile.am
# ViennaRNA-2.7.0/misc/rna_mod_purine_parameters.json
# ViennaRNA-2.7.0/misc/rna_turner2004.par
# ViennaRNA-2.7.0/misc/rna_turner1999.par
# ViennaRNA-2.7.0/misc/rna_mod_m5C_parameters.json
# ViennaRNA-2.7.0/misc/rna_mod_m6A_parameters.json
# ViennaRNA-2.7.0/setup.py.in
# ViennaRNA-2.7.0/doc/
# ViennaRNA-2.7.0/doc/source/
# ViennaRNA-2.7.0/doc/source/landscape/
# ViennaRNA-2.7.0/doc/source/landscape/paths.rst
# ViennaRNA-2.7.0/doc/source/landscape/paths_deprecated.rst
# ViennaRNA-2.7.0/doc/source/landscape/paths_walk.rst
# ViennaRNA-2.7.0/doc/source/landscape/paths_direct.rst
# ViennaRNA-2.7.0/doc/source/landscape/neighbors.rst
# ViennaRNA-2.7.0/doc/source/partfunc/
# ViennaRNA-2.7.0/doc/source/partfunc/thermodynamics.rst
# ViennaRNA-2.7.0/doc/source/partfunc/global.rst
# ViennaRNA-2.7.0/doc/source/partfunc/window.rst
# ViennaRNA-2.7.0/doc/source/partfunc/global_deprecated.rst
# ViennaRNA-2.7.0/doc/source/partfunc/window_deprecated.rst
# ViennaRNA-2.7.0/doc/source/io.rst
# ViennaRNA-2.7.0/doc/source/mfe.rst
# ViennaRNA-2.7.0/doc/source/files.rst
# ViennaRNA-2.7.0/doc/source/utilities.rst
# ViennaRNA-2.7.0/doc/source/using_rnalib.rst
# ViennaRNA-2.7.0/doc/source/probing/
# ViennaRNA-2.7.0/doc/source/probing/SHAPE.rst
# ViennaRNA-2.7.0/doc/source/probing/perturbation.rst
# ViennaRNA-2.7.0/doc/source/classified/
# ViennaRNA-2.7.0/doc/source/classified/kl_neighborhood.rst
# ViennaRNA-2.7.0/doc/source/classified/dos.rst
# ViennaRNA-2.7.0/doc/source/subopt_and_representatives.rst
# ViennaRNA-2.7.0/doc/source/mfe/
# ViennaRNA-2.7.0/doc/source/mfe/global.rst
# ViennaRNA-2.7.0/doc/source/mfe/backtracking.rst
# ViennaRNA-2.7.0/doc/source/mfe/window.rst
# ViennaRNA-2.7.0/doc/source/mfe/global_deprecated.rst
# ViennaRNA-2.7.0/doc/source/mfe/window_deprecated.rst
# ViennaRNA-2.7.0/doc/source/subopt/
# ViennaRNA-2.7.0/doc/source/subopt/mea.rst
# ViennaRNA-2.7.0/doc/source/subopt/stochbt.rst
# ViennaRNA-2.7.0/doc/source/subopt/centroid.rst
# ViennaRNA-2.7.0/doc/source/subopt/zuker.rst
# ViennaRNA-2.7.0/doc/source/subopt/wuchty.rst
# ViennaRNA-2.7.0/doc/source/man/
# ViennaRNA-2.7.0/doc/source/man/RNAdistance.rst
# ViennaRNA-2.7.0/doc/source/man/RNAPKplex.rst
# ViennaRNA-2.7.0/doc/source/man/RNAdos.rst
# ViennaRNA-2.7.0/doc/source/man/Makefile.in
# ViennaRNA-2.7.0/doc/source/man/Makefile
# ViennaRNA-2.7.0/doc/source/man/RNAduplex.rst
# ViennaRNA-2.7.0/doc/source/man/RNAfold.rst
# ViennaRNA-2.7.0/doc/source/man/RNApdist.rst
# ViennaRNA-2.7.0/doc/source/man/RNAmultifold.rst
# ViennaRNA-2.7.0/doc/source/man/RNAsubopt.rst
# ViennaRNA-2.7.0/doc/source/man/RNALfold.rst
# ViennaRNA-2.7.0/doc/source/man/RNAeval.rst
# ViennaRNA-2.7.0/doc/source/man/RNAaliduplex.rst
# ViennaRNA-2.7.0/doc/source/man/.gitignore
# ViennaRNA-2.7.0/doc/source/man/RNAalifold.rst
# ViennaRNA-2.7.0/doc/source/man/RNAsnoop.rst
# ViennaRNA-2.7.0/doc/source/man/RNAup.rst
# ViennaRNA-2.7.0/doc/source/man/RNAcofold.rst
# ViennaRNA-2.7.0/doc/source/man/RNAinverse.rst
# ViennaRNA-2.7.0/doc/source/man/RNAplot.rst
# ViennaRNA-2.7.0/doc/source/man/RNAparconv.rst
# ViennaRNA-2.7.0/doc/source/man/RNA2Dfold.rst
# ViennaRNA-2.7.0/doc/source/man/RNAplfold.rst
# ViennaRNA-2.7.0/doc/source/man/RNApaln.rst
# ViennaRNA-2.7.0/doc/source/man/Makefile.am
# ViennaRNA-2.7.0/doc/source/man/RNAplex.rst
# ViennaRNA-2.7.0/doc/source/man/RNALalifold.rst
# ViennaRNA-2.7.0/doc/source/man/RNAheat.rst
# ViennaRNA-2.7.0/doc/source/man/RNApvmin.rst
# ViennaRNA-2.7.0/doc/source/_static/
# ViennaRNA-2.7.0/doc/source/_static/css/
# ViennaRNA-2.7.0/doc/source/_static/css/custom.css
# ViennaRNA-2.7.0/doc/source/_static/js/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/tex-chtml.js
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/tex.js
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_AMS-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Size3-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_SansSerif-Italic.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Math-BoldItalic.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Typewriter-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Math-Italic.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Vector-Bold.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Zero.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Vector-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Size2-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Main-Italic.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Calligraphic-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Fraktur-Bold.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Script-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Main-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_SansSerif-Bold.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Calligraphic-Bold.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Math-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_SansSerif-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Size1-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Main-Bold.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Fraktur-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml/fonts/woff-v2/MathJax_Size4-Regular.woff
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/svg.js
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/chtml.js
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/svg/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/svg/fonts/
# ViennaRNA-2.7.0/doc/source/_static/js/mathjax/output/svg/fonts/tex.js
# ViennaRNA-2.7.0/doc/source/tutorial/
# ViennaRNA-2.7.0/doc/source/tutorial/RNAduplex.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNAfold.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNAsubopt.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNAalifold.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNAcofold.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNAinverse.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNAplot.rst
# ViennaRNA-2.7.0/doc/source/tutorial/barriers_treekin.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNA2Dfold.rst
# ViennaRNA-2.7.0/doc/source/tutorial/switch.rst
# ViennaRNA-2.7.0/doc/source/tutorial/RNApvmin.rst
# ViennaRNA-2.7.0/doc/source/configuration.rst
# ViennaRNA-2.7.0/doc/source/gfx/
# ViennaRNA-2.7.0/doc/source/gfx/5srel.png
# ViennaRNA-2.7.0/doc/source/gfx/Crecursion.png
# ViennaRNA-2.7.0/doc/source/gfx/shift_move_intervals.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml_up.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml_stem.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_stem.svg
# ViennaRNA-2.7.0/doc/source/gfx/vrna_96.png
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml_coaxial.svg
# ViennaRNA-2.7.0/doc/source/gfx/loop_types.png
# ViennaRNA-2.7.0/doc/source/gfx/5srel.eps
# ViennaRNA-2.7.0/doc/source/gfx/TAR_cmt.eps
# ViennaRNA-2.7.0/doc/source/gfx/TAR_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/5smnt.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad_pattern.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/RybB_ss.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/theo_aptamer.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/5S_mt.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/switch_barriertree_e13.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/2dfold_out_m.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/forties_50nM_dp.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/FOO_dp.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/alirna.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/5S_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/OmpN_cofold.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/5S_mt.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/t_ss.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/2dfold_2_out_m.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/RybB_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/FOO.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/tree.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/tree.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/switch_treekin.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/alidot.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/5S_rot.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/tconcdep.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/test_dp.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/2dfold_2_out_m.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/t_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/switch_treekin.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/OmpN_cofold.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/t_dp.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/t_dp.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/2dfold_out_m.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/theo_aptamer.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/switch_barriertree_e13.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/5S_rot.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/forties_50nM_dp.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/ompN_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/forties_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad_menon_nice.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/forties_ss.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/FOO.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/5S_ss.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/switch_barriertree.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/test_dp.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/switch_barriertree.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/FOO_dp.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad_pattern.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/test_ss.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/alidot.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad_menon_nice.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/tconcdep.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/ompN_ss.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad_menon.png
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/test_ss.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/alirna.eps
# ViennaRNA-2.7.0/doc/source/gfx/tutorial/gquad_menon.eps
# ViennaRNA-2.7.0/doc/source/gfx/Crecursion.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml.svg
# ViennaRNA-2.7.0/doc/source/gfx/ligands_up_callback.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml_ml_ml.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_up.svg
# ViennaRNA-2.7.0/doc/source/gfx/shift_move_intervals.png
# ViennaRNA-2.7.0/doc/source/gfx/vrna_32.png
# ViennaRNA-2.7.0/doc/source/gfx/recursions.png
# ViennaRNA-2.7.0/doc/source/gfx/theo_aptamer.svg
# ViennaRNA-2.7.0/doc/source/gfx/vrna_logo.png
# ViennaRNA-2.7.0/doc/source/gfx/decomp_il.svg
# ViennaRNA-2.7.0/doc/source/gfx/loop_decomposition.png
# ViennaRNA-2.7.0/doc/source/gfx/B_prod_rule.svg
# ViennaRNA-2.7.0/doc/source/gfx/vrna_48.png
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml_ml_stem.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_hp.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_ext_ext.svg
# ViennaRNA-2.7.0/doc/source/gfx/GCrecursion.svg
# ViennaRNA-2.7.0/doc/source/gfx/vrna.png
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_ext.svg
# ViennaRNA-2.7.0/doc/source/gfx/Grecursion.png
# ViennaRNA-2.7.0/doc/source/gfx/5smnt.png
# ViennaRNA-2.7.0/doc/source/gfx/loop_types.svg
# ViennaRNA-2.7.0/doc/source/gfx/GCrecursion.png
# ViennaRNA-2.7.0/doc/source/gfx/TAR_aln.png
# ViennaRNA-2.7.0/doc/source/gfx/bracket.png
# ViennaRNA-2.7.0/doc/source/gfx/recursions.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_ext_stem1.svg
# ViennaRNA-2.7.0/doc/source/gfx/vrna_16.png
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_ext_stem.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ml_ml.svg
# ViennaRNA-2.7.0/doc/source/gfx/TAR_cmt.png
# ViennaRNA-2.7.0/doc/source/gfx/loop_decomposition.svg
# ViennaRNA-2.7.0/doc/source/gfx/Grecursion.svg
# ViennaRNA-2.7.0/doc/source/gfx/decomp_ext_stem_ext.svg
# ViennaRNA-2.7.0/doc/source/gfx/TAR_aln.eps
# ViennaRNA-2.7.0/doc/source/gfx/TAR_ss.eps
# ViennaRNA-2.7.0/doc/source/eval/
# ViennaRNA-2.7.0/doc/source/eval/params/
# ViennaRNA-2.7.0/doc/source/eval/params/io.rst
# ViennaRNA-2.7.0/doc/source/eval/params/convert.rst
# ViennaRNA-2.7.0/doc/source/eval/params/salt.rst
# ViennaRNA-2.7.0/doc/source/eval/eval_deprecated.rst
# ViennaRNA-2.7.0/doc/source/eval/energy_parameters.rst
# ViennaRNA-2.7.0/doc/source/eval/eval_move.rst
# ViennaRNA-2.7.0/doc/source/eval/eval_structures.rst
# ViennaRNA-2.7.0/doc/source/eval/eval_loops.rst
# ViennaRNA-2.7.0/doc/source/citing.rst
# ViennaRNA-2.7.0/doc/source/index.rst
# ViennaRNA-2.7.0/doc/source/linking.rst
# ViennaRNA-2.7.0/doc/source/utils/
# ViennaRNA-2.7.0/doc/source/utils/io.rst
# ViennaRNA-2.7.0/doc/source/utils/strings.rst
# ViennaRNA-2.7.0/doc/source/utils/structures.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/
# ViennaRNA-2.7.0/doc/source/utils/struct/dotbracket.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/helix_list.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/metrics.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/pairtable.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/plist.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/abstract_shapes.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/deprecated.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/benchmark.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/trees.rst
# ViennaRNA-2.7.0/doc/source/utils/struct/wuss.rst
# ViennaRNA-2.7.0/doc/source/utils/search.rst
# ViennaRNA-2.7.0/doc/source/utils/plots/
# ViennaRNA-2.7.0/doc/source/utils/plots/annotation.rst
# ViennaRNA-2.7.0/doc/source/utils/plots/deprecated.rst
# ViennaRNA-2.7.0/doc/source/utils/plots/probabilities.rst
# ViennaRNA-2.7.0/doc/source/utils/plots/layouts.rst
# ViennaRNA-2.7.0/doc/source/utils/plots/alignments.rst
# ViennaRNA-2.7.0/doc/source/utils/logs.rst
# ViennaRNA-2.7.0/doc/source/utils/units.rst
# ViennaRNA-2.7.0/doc/source/utils/msa.rst
# ViennaRNA-2.7.0/doc/source/utils/msa_deprecated.rst
# ViennaRNA-2.7.0/doc/source/utils/combinatorics.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/
# ViennaRNA-2.7.0/doc/source/utils/datastructures/arrays.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/strings.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/fold_compound.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/hash_tables.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/buffers.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/heaps.rst
# ViennaRNA-2.7.0/doc/source/utils/datastructures/dp_matrices.rst
# ViennaRNA-2.7.0/doc/source/utils/io/
# ViennaRNA-2.7.0/doc/source/utils/io/file_formats_msa.rst
# ViennaRNA-2.7.0/doc/source/utils/io/commands.rst
# ViennaRNA-2.7.0/doc/source/utils/io/file_formats.rst
# ViennaRNA-2.7.0/doc/source/utils/alphabet.rst
# ViennaRNA-2.7.0/doc/source/utils/data_structures.rst
# ViennaRNA-2.7.0/doc/source/utils/messages.rst
# ViennaRNA-2.7.0/doc/source/utils/plots.rst
# ViennaRNA-2.7.0/doc/source/examples/
# ViennaRNA-2.7.0/doc/source/examples/perl5.rst
# ViennaRNA-2.7.0/doc/source/examples/python.rst
# ViennaRNA-2.7.0/doc/source/examples/c.rst
# ViennaRNA-2.7.0/doc/source/contributing.md
# ViennaRNA-2.7.0/doc/source/cofold.rst
# ViennaRNA-2.7.0/doc/source/modified_bases.rst
# ViennaRNA-2.7.0/doc/source/bibliography.rst
# ViennaRNA-2.7.0/doc/source/pf_fold.rst
# ViennaRNA-2.7.0/doc/source/license.md
# ViennaRNA-2.7.0/doc/source/callbacks.rst
# ViennaRNA-2.7.0/doc/source/landscape.rst
# ViennaRNA-2.7.0/doc/source/changelog.md
# ViennaRNA-2.7.0/doc/source/grammar.rst
# ViennaRNA-2.7.0/doc/source/install.rst
# ViennaRNA-2.7.0/doc/source/vrna_3.0.rst
# ViennaRNA-2.7.0/doc/source/eval.rst
# ViennaRNA-2.7.0/doc/source/api.rst
# ViennaRNA-2.7.0/doc/source/install.rst.in
# ViennaRNA-2.7.0/doc/source/inverse.rst
# ViennaRNA-2.7.0/doc/source/probing_data.rst
# ViennaRNA-2.7.0/doc/source/manpages.rst
# ViennaRNA-2.7.0/doc/source/_templates/
# ViennaRNA-2.7.0/doc/source/_templates/breadcrumbs.html
# ViennaRNA-2.7.0/doc/source/_templates/layout.html
# ViennaRNA-2.7.0/doc/source/news.md
# ViennaRNA-2.7.0/doc/source/io/
# ViennaRNA-2.7.0/doc/source/io/parameters.rst
# ViennaRNA-2.7.0/doc/source/io/msa.rst
# ViennaRNA-2.7.0/doc/source/io/commands.rst
# ViennaRNA-2.7.0/doc/source/io/rna_structures.rst
# ViennaRNA-2.7.0/doc/source/paired_modules.rst
# ViennaRNA-2.7.0/doc/source/conf.py.in
# ViennaRNA-2.7.0/doc/source/faq.rst
# ViennaRNA-2.7.0/doc/source/deprecated.rst
# ViennaRNA-2.7.0/doc/source/ligands/
# ViennaRNA-2.7.0/doc/source/ligands/unstructured_domains.rst
# ViennaRNA-2.7.0/doc/source/ligands/constraints.rst
# ViennaRNA-2.7.0/doc/source/wrappers.rst
# ViennaRNA-2.7.0/doc/source/api_python.rst
# ViennaRNA-2.7.0/doc/source/ligand_binding.rst
# ViennaRNA-2.7.0/doc/source/conf.py
# ViennaRNA-2.7.0/doc/source/rip/
# ViennaRNA-2.7.0/doc/source/rip/up.rst
# ViennaRNA-2.7.0/doc/source/rip/pf.rst
# ViennaRNA-2.7.0/doc/source/utils.rst
# ViennaRNA-2.7.0/doc/source/modules/
# ViennaRNA-2.7.0/doc/source/modules/pseudoknots.rst
# ViennaRNA-2.7.0/doc/source/modules/gquads.rst
# ViennaRNA-2.7.0/doc/source/getting_started.rst
# ViennaRNA-2.7.0/doc/source/class_fold.rst
# ViennaRNA-2.7.0/doc/source/grammar/
# ViennaRNA-2.7.0/doc/source/grammar/constraints.rst
# ViennaRNA-2.7.0/doc/source/grammar/domains_struc.rst
# ViennaRNA-2.7.0/doc/source/grammar/model_details.rst
# ViennaRNA-2.7.0/doc/source/grammar/domains_up.rst
# ViennaRNA-2.7.0/doc/source/grammar/constraints/
# ViennaRNA-2.7.0/doc/source/grammar/constraints/soft.rst
# ViennaRNA-2.7.0/doc/source/grammar/constraints/hard.rst
# ViennaRNA-2.7.0/doc/viennarna.bib
# ViennaRNA-2.7.0/doc/man2rst.py
# ViennaRNA-2.7.0/doc/Makefile.in
# ViennaRNA-2.7.0/doc/RNAlib-2.7.0.pdf
# ViennaRNA-2.7.0/doc/refman-html
# ViennaRNA-2.7.0/doc/breathe/
# ViennaRNA-2.7.0/doc/breathe/Makefile
# ViennaRNA-2.7.0/doc/breathe/CHANGELOG.rst
# ViennaRNA-2.7.0/doc/breathe/pyproject.toml
# ViennaRNA-2.7.0/doc/breathe/setup.cfg
# ViennaRNA-2.7.0/doc/breathe/breathe/
# ViennaRNA-2.7.0/doc/breathe/breathe/__init__.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/file.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__init__.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/item.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/function.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/content_block.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/class_like.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/setup.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/index.py
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/content_block.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/item.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/file.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/function.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/item.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/setup.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/class_like.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/content_block.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/index.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/__init__.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/index.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/file.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/__init__.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/class_like.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/setup.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/directives/__pycache__/function.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/process.py
# ViennaRNA-2.7.0/doc/breathe/breathe/project.py
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/compound.py
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__init__.py
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/index.py
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/factory.py
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/compound.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/factory.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/compound.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/index.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/__init__.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/index.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/__init__.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/finder/__pycache__/factory.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/filetypes.py
# ViennaRNA-2.7.0/doc/breathe/breathe/path_handler.py
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/compound.py
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/indexsuper.py
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__init__.py
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/compoundsuper.py
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/index.py
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/compoundsuper.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/compound.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/compound.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/indexsuper.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/indexsuper.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/compoundsuper.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/index.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/__init__.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/index.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/parser/__pycache__/__init__.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/README.rst
# ViennaRNA-2.7.0/doc/breathe/breathe/apidoc.py
# ViennaRNA-2.7.0/doc/breathe/breathe/exception.py
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/file_state_cache.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/file_state_cache.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/path_handler.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/filetypes.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/project.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/path_handler.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/project.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/exception.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/__init__.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/filetypes.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/__init__.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/exception.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/process.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/__pycache__/process.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/mask.py
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__init__.py
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/filter.py
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/target.py
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/sphinxrenderer.py
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/mask.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/filter.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/mask.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/target.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/sphinxrenderer.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/filter.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/target.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/__init__.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/__init__.cpython-311.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/renderer/__pycache__/sphinxrenderer.cpython-312.pyc
# ViennaRNA-2.7.0/doc/breathe/breathe/file_state_cache.py
# ViennaRNA-2.7.0/doc/breathe/examples/
# ViennaRNA-2.7.0/doc/breathe/examples/specific/
# ViennaRNA-2.7.0/doc/breathe/examples/specific/using_in_ns.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_typedef.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/define.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_union.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/multifile.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/typedef.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_enum.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/dot_graphs.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/alias.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/headings.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/tables.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/typedef.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_constexpr_hax.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/image.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/alias.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/enum.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/headerfile.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_enum.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/lists.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/nutshell.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_file.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_specialisation.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_inherited_members.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/array.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/rst.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/inheritance.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_inherited_members.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/Makefile
# ViennaRNA-2.7.0/doc/breathe/examples/specific/using_in_ns.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/decl_impl.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/specific/programlisting.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_function_lookup.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/rst.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/latexmath.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/qtsignalsandslots.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_class_non_type.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/array.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/headerfile.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_struct.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/programlistinginclude.txt
# ViennaRNA-2.7.0/doc/breathe/examples/specific/simplesect.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_friendclass.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/interface.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_anon.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/members.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/struct.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_type_alias.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/define.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_macro.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/struct_function.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/enum.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/programlisting.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_union.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/union.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/membergroups.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_function.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/interface.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/nutshell.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_enum.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_union.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_function.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/xrefsect.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/inline.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/lists.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/xrefsect.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/.gitignore
# ViennaRNA-2.7.0/doc/breathe/examples/specific/class.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/specific/qtsignalsandslots.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_specialisation.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/auto_function.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/name.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/links.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/functionOverload.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_macro.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/decl_impl.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_function.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/name.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/image.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_type_alias.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/members.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/multifile/
# ViennaRNA-2.7.0/doc/breathe/examples/specific/multifile/one/
# ViennaRNA-2.7.0/doc/breathe/examples/specific/multifile/one/Util.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/multifile/two/
# ViennaRNA-2.7.0/doc/breathe/examples/specific/multifile/two/Util.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/auto_class.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/namespacefile.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_trailing_return_type.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/parameters.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/union.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/fixedwidthfont.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/struct_function.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_function.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/code_blocks.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_anon.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/group.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/dot_graphs.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_friendclass.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_concept.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/namespacefile.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/links.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_class.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/simplesect.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/group.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/struct.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/userdefined.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/imageExample.png
# ViennaRNA-2.7.0/doc/breathe/examples/specific/class.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_typedef.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/parameters.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/fixedwidthfont.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/decl_impl.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_class.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_constexpr_hax.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_enum.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_function_lookup.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/template_class_non_type.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_file.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/dotfile.dot
# ViennaRNA-2.7.0/doc/breathe/examples/specific/c_struct.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_concept.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/class.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/membergroups.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_union.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/cpp_trailing_return_type.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/inheritance.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/functionOverload.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/inline.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/auto.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/tables.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/code_blocks.h
# ViennaRNA-2.7.0/doc/breathe/examples/specific/latexmath.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/userdefined.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/specific/headings.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/func.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/define.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/qtstyle.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/autolink.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/templ.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/example.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/tag.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/relates.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/enum.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/example_test.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/manual.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/manual.c
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/author.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/restypedef.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/Makefile
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/overload.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/docstring.py
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/diagrams.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/diagrams_b.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/diagrams_d.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/memgrp.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/diagrams_a.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/interface.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/concept.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/jdstyle.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/file.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/define.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/enum.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/page.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/interface.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/afterdoc.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/func.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/group.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/example.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/.gitignore
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/docstring.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/parblock.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/diagrams_e.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/afterdoc.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/relates.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/par.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/include.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/memgrp.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/qtstyle.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/structcmd.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/group.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/diagrams_c.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/par.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/structcmd.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/class.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/jdstyle.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/overload.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/concept.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/tag.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/pyexample.py
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/include.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/author.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/file.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/templ.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/autolink.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/page.doc
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/class.h
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/pyexample.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/parblock.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/doxygen/restypedef.cpp
# ViennaRNA-2.7.0/doc/breathe/examples/tinyxml/
# ViennaRNA-2.7.0/doc/breathe/examples/tinyxml/Makefile
# ViennaRNA-2.7.0/doc/breathe/examples/tinyxml/tinyxml.h
# ViennaRNA-2.7.0/doc/breathe/examples/tinyxml/tinyxml.cfg
# ViennaRNA-2.7.0/doc/breathe/examples/tinyxml/.gitignore
# ViennaRNA-2.7.0/doc/breathe/documentation/
# ViennaRNA-2.7.0/doc/breathe/documentation/source/
# ViennaRNA-2.7.0/doc/breathe/documentation/source/typedef.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/function.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/contributing.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/latexmath.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/autoindex.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/class.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/credits.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/group.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/concept.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/lists.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/_static/
# ViennaRNA-2.7.0/doc/breathe/documentation/source/_static/favicon.ico
# ViennaRNA-2.7.0/doc/breathe/documentation/source/_static/logo.svg
# ViennaRNA-2.7.0/doc/breathe/documentation/source/_static/breathe.css
# ViennaRNA-2.7.0/doc/breathe/documentation/source/groups.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/customcss.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/specific.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/quickstart.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/index.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/template.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/inline.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/nested_list_3.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/namespaces.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/nested_list_5.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/nutshell.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/nested_list_2.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/nested_list_1.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/nested_list_4.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/code/groups.h
# ViennaRNA-2.7.0/doc/breathe/documentation/source/namespace.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/readthedocs.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/enum.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/struct.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/define.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/autofile.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/embeddedrst.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/testpages.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/spelling_wordlist.txt
# ViennaRNA-2.7.0/doc/breathe/documentation/source/differences.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/doxygen.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/tinyxml.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/union.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/page.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/tables.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/codeblocks.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/variable.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/domains.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/conf.py
# ViennaRNA-2.7.0/doc/breathe/documentation/source/markups.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/directives.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/file.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/members.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/enumvalue.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/dot_graphs.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/source/codeguide.rst
# ViennaRNA-2.7.0/doc/breathe/documentation/Makefile
# ViennaRNA-2.7.0/doc/breathe/documentation/compare
# ViennaRNA-2.7.0/doc/breathe/documentation/.gitignore
# ViennaRNA-2.7.0/doc/breathe/documentation/environment.yaml
# ViennaRNA-2.7.0/doc/breathe/.gitignore
# ViennaRNA-2.7.0/doc/breathe/tests/
# ViennaRNA-2.7.0/doc/breathe/tests/runtests.sh
# ViennaRNA-2.7.0/doc/breathe/tests/test_utils.py
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/function.rst
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/class.rst
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/group.rst
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/index.rst
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/define.rst
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/source/conf.py
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/Makefile
# ViennaRNA-2.7.0/doc/breathe/tests/warnings/make.bat
# ViennaRNA-2.7.0/doc/breathe/tests/data/
# ViennaRNA-2.7.0/doc/breathe/tests/data/ellipsis.xml
# ViennaRNA-2.7.0/doc/breathe/tests/data/arange.xml
# ViennaRNA-2.7.0/doc/breathe/tests/test_renderer.py
# ViennaRNA-2.7.0/doc/breathe/breathe-apidoc.py
# ViennaRNA-2.7.0/doc/breathe/.github/
# ViennaRNA-2.7.0/doc/breathe/.github/FUNDING.yml
# ViennaRNA-2.7.0/doc/breathe/.github/workflows/
# ViennaRNA-2.7.0/doc/breathe/.github/workflows/unit_tests.yml
# ViennaRNA-2.7.0/doc/breathe/.github/workflows/documentation.yml
# ViennaRNA-2.7.0/doc/breathe/.github/workflows/lint.yml
# ViennaRNA-2.7.0/doc/breathe/CONTRIBUTING.rst
# ViennaRNA-2.7.0/doc/breathe/setup.py
# ViennaRNA-2.7.0/doc/breathe/mypy.ini
# ViennaRNA-2.7.0/doc/breathe/requirements/
# ViennaRNA-2.7.0/doc/breathe/requirements/production.txt
# ViennaRNA-2.7.0/doc/breathe/requirements/development.txt
# ViennaRNA-2.7.0/doc/breathe/.readthedocs.yaml
# ViennaRNA-2.7.0/doc/breathe/README.rst
# ViennaRNA-2.7.0/doc/breathe/mkrelease
# ViennaRNA-2.7.0/doc/breathe/CONTRIBUTORS.rst
# ViennaRNA-2.7.0/doc/breathe/LICENSE
# ViennaRNA-2.7.0/doc/breathe/scripts/
# ViennaRNA-2.7.0/doc/breathe/scripts/version-check.py
# ViennaRNA-2.7.0/doc/CLA/
# ViennaRNA-2.7.0/doc/CLA/ViennaRNA-CLA-Individual.pdf
# ViennaRNA-2.7.0/doc/CLA/Makefile.in
# ViennaRNA-2.7.0/doc/CLA/ViennaRNA-CLA-Entity.pdf
# ViennaRNA-2.7.0/doc/CLA/Makefile.am
# ViennaRNA-2.7.0/doc/CLA/CLA-Individual.tex
# ViennaRNA-2.7.0/doc/CLA/CLA-Entity.tex
# ViennaRNA-2.7.0/doc/doxygen/
# ViennaRNA-2.7.0/doc/doxygen/Makefile.in
# ViennaRNA-2.7.0/doc/doxygen/DoxygenLayout.xml
# ViennaRNA-2.7.0/doc/doxygen/xml/
# ...
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0048_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0044_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0026_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0044_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0046_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0020_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0025_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0006_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0050_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0020_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0013_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0026_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0011_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0031_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0025_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0024_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0048_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0037_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0011_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0041_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0021_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0030_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0010_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0017_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0011_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0029_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.pf.full.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0005_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0047_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0049_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0008_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0004_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0045_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0003_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0002_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0032_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0020_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0008_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0030_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0040_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0033_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0047_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0041_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0047_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0033_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0007_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0043_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0013_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.d1.mfe.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0003_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0048_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0050_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0028_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0019_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.rna_andronescu2007.par.mfe.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0026_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0032_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0023_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0035_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0017_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0015_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0009_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0016_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0006_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0042_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0021_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0034_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0049_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0026_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0011_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0037_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0004_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0022_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0031_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0014_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0031_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0005_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0009_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0012_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0019_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.d2.mfe.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0049_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0025_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0023_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0012_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0049_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0033_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0040_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0032_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0009_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0036_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0008_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0010_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0015_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0032_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0046_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0001_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0012_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.dna_mathews1999.par.mfe.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0005_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0009_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0027_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0016_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0003_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0022_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0033_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0005_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0007_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0044_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.noLP.mfe.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0041_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0032_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0013_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0001_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0018_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0034_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0008_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0027_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0029_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0041_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0048_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0007_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0041_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.pf.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0017_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0024_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0045_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0003_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0043_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0027_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0038_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0028_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0040_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0013_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0025_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0039_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0027_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0042_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0002_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0011_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/ABrnacofold_pf_test_0016_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0004_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Brnacofold_pf_test_0024_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/BBrnacofold_pf_test_0036_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.d0.mfe.gold
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0022_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0038_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/AArnacofold_pf_test_0014_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/Arnacofold_pf_test_0023_dp5.ps
# ViennaRNA-2.7.0/tests/RNAcofold/results/rnacofold.small.dna_mathews2004.par.mfe.gold
# ViennaRNA-2.7.0/tests/neighbor.ts
# ViennaRNA-2.7.0/tests/Makefile.am
# ViennaRNA-2.7.0/tests/hash_table.c
# ViennaRNA-2.7.0/tests/fold.ts
# ViennaRNA-2.7.0/tests/RNAHelpers.pm.in
# ViennaRNA-2.7.0/tests/energy_evaluation.ts
# ViennaRNA-2.7.0/tests/python2/
# ViennaRNA-2.7.0/tests/python2/test-RNA-pf_window.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-mfe_window.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-utils.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-mfe_eval.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-constraints-SHAPE.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-constraints.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-constraints-special.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-combinatorics.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-file-formats.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-sc-callbacks.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-subopt.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-ensemble_defect.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-constraints-soft.py2
# ViennaRNA-2.7.0/tests/python2/test-RNA-boltzmann-sampling.py2
# ViennaRNA-2.7.0/tests/ensemble_defect.ts
# ViennaRNA-2.7.0/tests/data/
# ViennaRNA-2.7.0/tests/data/hc.txt
# ViennaRNA-2.7.0/tests/data/rnafold_sc_lift.cmds
# ViennaRNA-2.7.0/tests/data/5domain16S_rRNA_E.coli.pvmin
# ViennaRNA-2.7.0/tests/data/alignment_stockholm.stk
# ViennaRNA-2.7.0/tests/data/Lysine_riboswitch_T._martima.shape_2rows
# ViennaRNA-2.7.0/tests/data/rnacofold.small.seq
# ViennaRNA-2.7.0/tests/data/adam10_5utr.aln
# ViennaRNA-2.7.0/tests/data/rfam_seed_selected.stk
# ViennaRNA-2.7.0/tests/data/alignment_1.shape_2rows
# ViennaRNA-2.7.0/tests/data/rnafold.cmds
# ViennaRNA-2.7.0/tests/data/Lysine_riboswitch_T._martima.pvmin
# ViennaRNA-2.7.0/tests/data/rnafold.small.seq
# ViennaRNA-2.7.0/tests/data/rnafold.fasta
# ViennaRNA-2.7.0/tests/data/ecoli_16S_1m7.shape
# ViennaRNA-2.7.0/tests/data/alignment_fasta.fa
# ViennaRNA-2.7.0/tests/data/crem_5utr.aln
# ViennaRNA-2.7.0/tests/data/rnafold.seq
# ViennaRNA-2.7.0/tests/data/5domain16S_rRNA_H.volcanii.db
# ViennaRNA-2.7.0/tests/data/TPP_riboswitch_E.coli.stk
# ViennaRNA-2.7.0/tests/data/rfam_seed_many_short.stk
# ViennaRNA-2.7.0/tests/data/test.maf
# ViennaRNA-2.7.0/tests/data/070313_ecoli_cdiff_16S_fasta.aln
# ViennaRNA-2.7.0/tests/data/rna.ps
# ViennaRNA-2.7.0/tests/data/5domain16S_rRNA_H.volcanii.shape_2rows
# ViennaRNA-2.7.0/tests/data/rnacofold.concentrations
# ViennaRNA-2.7.0/tests/data/5domain16S_rRNA_E.coli.db
# ViennaRNA-2.7.0/tests/data/cdiff_16S_1m7.shape
# ViennaRNA-2.7.0/tests/data/TPP_riboswitch_E.coli.shape_2rows
# ViennaRNA-2.7.0/tests/data/TPP_riboswitch_E.coli.pvmin
# ViennaRNA-2.7.0/tests/data/Lysine_riboswitch_T._martima.db
# ViennaRNA-2.7.0/tests/data/rnafold.theo.fa
# ViennaRNA-2.7.0/tests/data/ebag9_5utr.aln
# ViennaRNA-2.7.0/tests/data/alignment_clustal.aln
# ViennaRNA-2.7.0/tests/data/ncam2_5utr.aln
# ViennaRNA-2.7.0/tests/data/070313_ecoli_cdiff_16S_clustalw.aln
# ViennaRNA-2.7.0/tests/data/output_test.txt
# ViennaRNA-2.7.0/tests/data/rnafold.gquad.fa
# ViennaRNA-2.7.0/tests/data/5domain16S_rRNA_H.volcanii.pvmin
# ViennaRNA-2.7.0/tests/data/bcl-2_5utr.aln
# ViennaRNA-2.7.0/tests/data/alignment_maf.maf
# ViennaRNA-2.7.0/tests/data/TPP_riboswitch_E.coli.db
# ViennaRNA-2.7.0/tests/data/sc.txt
# ViennaRNA-2.7.0/tests/data/5domain16S_rRNA_E.coli.shape_2rows
# ViennaRNA-2.7.0/tests/data/rnafold_hc.cmds
# ViennaRNA-2.7.0/tests/data/alignment_2.shape_2rows
# ViennaRNA-2.7.0/CHANGELOG.md
# ViennaRNA-2.7.0/depcomp
# ViennaRNA-2.7.0/config/
# ViennaRNA-2.7.0/config/config.guess
# ViennaRNA-2.7.0/config/compile
# ViennaRNA-2.7.0/config/config.sub
# ViennaRNA-2.7.0/config/tap-driver.sh
# ViennaRNA-2.7.0/config/missing
# ViennaRNA-2.7.0/config/texinfo.tex
# ViennaRNA-2.7.0/config/depcomp
# ViennaRNA-2.7.0/config/install-sh
# ViennaRNA-2.7.0/config/ltmain.sh
# ViennaRNA-2.7.0/config/ar-lib
# ViennaRNA-2.7.0/config/py-compile
# ViennaRNA-2.7.0/Makefile.am
# ViennaRNA-2.7.0/m4/
# ViennaRNA-2.7.0/m4/ax_pkg_swig.m4
# ViennaRNA-2.7.0/m4/ltsugar.m4
# ViennaRNA-2.7.0/m4/ax_python3_devel.m4
# ViennaRNA-2.7.0/m4/libtool.m4
# ViennaRNA-2.7.0/m4/ac_rna_colorize.m4
# ViennaRNA-2.7.0/m4/ac_rna_unit_tests.m4
# ViennaRNA-2.7.0/m4/ac_rna_lto.m4
# ViennaRNA-2.7.0/m4/ac_rna_osx.m4
# ViennaRNA-2.7.0/m4/ac_rna_build_requirements.m4
# ViennaRNA-2.7.0/m4/lt~obsolete.m4
# ViennaRNA-2.7.0/m4/ax_compiler_vendor.m4
# ViennaRNA-2.7.0/m4/ac_rna_refman.m4
# ViennaRNA-2.7.0/m4/ax_perl_ext.m4
# ViennaRNA-2.7.0/m4/ax_python2_devel.m4
# ViennaRNA-2.7.0/m4/ax_require_defined.m4
# ViennaRNA-2.7.0/m4/ax_pthread.m4
# ViennaRNA-2.7.0/m4/ac_rna_features.m4
# ViennaRNA-2.7.0/m4/ax_openmp.m4
# ViennaRNA-2.7.0/m4/ax_check_link_flag.m4
# ViennaRNA-2.7.0/m4/ltversion.m4
# ViennaRNA-2.7.0/m4/ac_rna_macros.m4
# ViennaRNA-2.7.0/m4/ac_rna_latex.m4
# ViennaRNA-2.7.0/m4/ltoptions.m4
# ViennaRNA-2.7.0/m4/ax_cxx_compile_stdcxx.m4
# ViennaRNA-2.7.0/m4/ac_rna_cla.m4
# ViennaRNA-2.7.0/m4/ac_rna.m4
# ViennaRNA-2.7.0/m4/ax_check_compile_flag.m4
# ViennaRNA-2.7.0/m4/ax_append_flag.m4
# ViennaRNA-2.7.0/m4/ac_rna_swig.m4
# ViennaRNA-2.7.0/m4/ac_rna_subpackages.m4
# ViennaRNA-2.7.0/INSTALL
# ViennaRNA-2.7.0/pyproject.toml.in
# ViennaRNA-2.7.0/AUTHORS
# ViennaRNA-2.7.0/THANKS
# /bin/bash: line 1: ./configure: No such file or directory
# make: *** No targets specified and no makefile found.  Stop.
# [sudo] password for koeksalr:

# %% [markdown]
# Import needed libraries

# %%
import glob
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from  torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch import nn, optim
from sklearn.metrics import average_precision_score
from sklearn.model_selection import KFold
from torch_geometric.data import Data
import itertools
import uuid
import subprocess as sp
import os
import torch.nn as nn
import torch.nn.functional as F
from torch import nn
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %% [markdown]
# ## Dataset Preprocessing
#
# The dataset consists of pairs ($s_i$, $v_i$) where:
#
# $s_i$: RNA sequence (string of nucleotides: A, U, C, G)
#
# $v_i$: Vector of likelihoods indicating the probability of each nucleotide in $s_i$ being unpaired (does NOT form a base pair in the corresponding RNA secondary structure)
#
# For example, an RNA sequence `AUGCGA` with DMS scores `[0.8, 0.2, 0.5, 0.9, 0.1, 0.7]`. Nucleotides with lower scores are more likely to be paired in the secondary structure. This will allow us to combine empirical data from DMS data by training our LSTM to predict these unpaired probabilties with the thermodynamic model from RNAfold.

# %% [markdown]
# To pre-process this data and prepare it into the train, validation, and test sets we need to train and evaluate our LSTM, we will define a custom PyTorch Dataset class.
#
# This implements the following pipeline:
# 1. Read RNA sequences and their DMS data from the downloaded file
# 2. Encode RNA sequences into numerical representations using k-mers
# 3. Prepare target values based on DMS scores
# 4. Create graph structures

# %%
class MyDataset(Dataset):

	def __init__(self, dataset_folder, kmer, scale_factor):
		self.scale_factor = scale_factor
		self.dataset_folder = dataset_folder
		self.kmer_list = self.get_kmer_list(kmer)
		
		value_list = self.read_dataset(self.dataset_folder)

		self.dataset, self.x_values, self.y_values, self.max_length, self.seq_list = self.construct_dataset(value_list, self.kmer_list)

		self.dataset = self.dataset
		self.x_values = self.x_values
		self.y_values = self.y_values
		self.seq_list = self.seq_list
		
		
	def concat(self, x_str):
		x_concat = ""
		for x in x_str:
			x_concat += x
	
		return x_concat
		
	def num_words(self):
		return len(self.kmer_list)
		
		
	def get_kmer_list(self, kmer):
		kmer_list = list(itertools.product(["A", "T", "G", "C"], repeat=kmer))
		kmer_list = [self.concat(x) for x in kmer_list]

		return kmer_list
		

	def read_dataset(self, file_):
		value_list = []
		id_list = []
		struct_list = []
		files  = open(file_)
		file_lines = files.readlines()
		
		for i in range(0,len(file_lines),3):
			# Each RNA entry consists of three lines: ID, RNA sequence, DMS probability list
			value_list.append([file_lines[i], file_lines[i + 1], file_lines[i+2]])
		
		files.close()

		return value_list
		
		
	def construct_dataset(self, value_list, kmer_list):
		print(kmer_list)
		x_values = []
		y_values = []
		data_list = []
		seq_list = []
		max_length = 0
		

		for sample in value_list:
			seq = sample[1][:-1]
			seq_list.append(seq)
			dms = [float(dms) for dms in sample[2][:-2].split(" ")]
			kmer_length = len(kmer_list[0])

			x_encoded = []
			y_encoded = []
			edge_list = []

			
			for num,step_size in enumerate(range(0, len(seq) - (kmer_length-1))):
				# For each k-mer in the sequence, extract k-mer DMS scores and bases respectively
				kmer_dms = dms[step_size :step_size + kmer_length]
				kmer_dms = [dms for num, dms in enumerate(kmer_dms)]
				kmer_bases = seq[step_size:step_size+kmer_length]

				listofzeros = kmer_list.index(kmer_bases)
				x_encoded.append(listofzeros)
				# Create bidirectional graph edge between consecutive k-mers
				edge_list.append([num, num+1])
				edge_list.append([num+1, num])

				# Use the maximum DMS score in the k-mer as the target
				y_encoded.append(np.max(kmer_dms))

			# DMS only affects bases A and C so only scale if nucleotide is A or C, otherwise set to 0
			y_encoded = [y*self.scale_factor if seq[num] == "A" or seq[num] == "C" else 0 for num, y in enumerate(y_encoded)]
			
			
			if len(x_encoded) > max_length: max_length = len(x_encoded) 
			
			
			max_length = len(kmer_list)
			
			# Append encoded features and targets
			x_values.append(x_encoded)
			y_values.append(y_encoded)
			
			# Create the graph data object
			# Nodes: indices representing k-mers from the RNA sequence
			# Edges: between consecutive k-mers, representing their sequential relationship in the RNA sequence 
			edge_index = torch.tensor(edge_list, dtype=torch.long)
			x = torch.tensor(x_encoded, dtype=torch.float)
			y = torch.tensor(y_encoded, dtype=torch.float)
	
			data = Data(x=x, y=y, edge_index=edge_index.t().contiguous(), id = str(sample[0]))
			data_list.append(data)
		
		 
			
		return data_list, x_values, y_values, max_length, seq_list
		
		
		
	def reconstruct_input(self, input_seq):
		# Rebuild original RNA sequence from list of k-mer indices by mapping each index back toits corresponding k-mer
		seq = ""
		for enum, val in enumerate(input_seq[0]):
				
			kmer = self.kmer_list[val]
			seq += kmer
	
		return seq
        	
        
	def __len__(self):
		return len(self.y_values)

	def __getitem__(self, idx):
		return self.x_values[idx], self.y_values[idx]
		
	def return_x(self):
		return self.x_values
		
	def return_y(self):
		return self.y_values

# %% [markdown]
# # LSTM Architecture
# Next we define our LSTM class using torch.nn modules

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, max_length):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.max_length = max_length
        self.LSTM = nn.LSTM(max_length, hidden_size, batch_first = True)
        self.out1 = nn.Linear(self.hidden_size, self.hidden_size//2)
        self.out2 = nn.Linear(self.hidden_size//2, 1)
        
    
    def forward(self, input, hidden):
    
        # Get the one-hot encoding of the RNA sequence input 
        hot_one = self.return_hotone(input)
        
        output, hidden = self.LSTM(hot_one, hidden)
        output = F.relu(output)
        output = F.relu(self.out1(output))
        output = self.out2(output)
        return output, hidden
    

    def initHidden(self):
        return (torch.zeros(1, 1, self.hidden_size), torch.zeros(1, 1, self.hidden_size))
        
    
    
    def return_hotone(self, input):
        hot_one_vec = []
        for batch in input:
    	    for val in batch:
                hot_one = [0] * self.max_length
                hot_one[val] = 1
                hot_one_vec.append(hot_one)
                
        return torch.FloatTensor([hot_one_vec])

# %% [markdown]
# Define a custom Pearson Correlation Coefficient loss function for the LSTM

# %%
def pearson_loss(output, target_data, input_data):
	# Center data to focus on covariance 
	vx = output - torch.mean(output)
	vy = target_data - torch.mean(target_data)
	
	loss = torch.sum(vx * vy) / (torch.sqrt(torch.sum(vx ** 2)) * torch.sqrt(torch.sum(vy ** 2)))
	
	return loss.item()

# %% [markdown]
# Define a custom collate method for preparing the batches of data during training

# %%
def my_collate(batch):
    data = [item[0] for item in batch]
    target = [torch.FloatTensor(item[1]) for item in batch]
    target = target
    return [data, target]

# %% [markdown]
# Load and prepare our dataset using the custom data class for the LSTM, both previously defined.

# %%
scale_factor  = 100
dataset = MyDataset("./dms_dataset.fa", kmer=1, scale_factor = scale_factor)
# Out:
# ['A', 'T', 'G', 'C']

# %% [markdown]
# Split processed dataset into 5 folds for 5-fold cross-validation.

# %%
# 2) Split dataset into 5 folds 
kfold_loss = []
fold_res = []
graph_sim_loss = []

kfold = KFold(n_splits=5, shuffle=False, random_state=None)

# %% [markdown]
# # Weisfeiler Lehman Algorithm
#
# For each fold, we will train our model for 10 epochs and then evaluate on the test data. We will then run RNAfold on the RNA sequences with two settings and compare the predictive performance:
#
# 1) With DMS feature vectors predicted by trained LSTM model (DMS + DL + thermodynamic model)
# 2) Only the RNA sequence ie. RNAfold alone (thermodynamic model only)
#
# Both of these results will be converted into graphs so that we can compute the graph similarity between them using the Weisfeiler Lehman algorithm.

# %%
class Weisfeiler_Lehman_Graph():
	def __init__(self):
		self.label_dict = {}
	
	
	def propagate_class_labels(self, seq1, connections1):
		new_labels_seq = []
	
		# Add label for linear connection
		for num, seq in enumerate(seq1):
			if num == 0:
				new_labels_seq.append(str(seq) + str(seq1[num+1]))
			elif num == len(seq1) -1:
				new_labels_seq.append(str(seq) + str(seq1[num-1]))
			else:
				new_labels_seq.append(str(seq) + str(seq1[num-1]) + str(seq1[num+1]))
			
		# Add label for rest connections
		for connection in connections1:
			new_labels_seq[connection[0]] += seq1[connection[1]]
			new_labels_seq[connection[1]] += seq1[connection[0]]

		# Label compression
		self.label_hashing(new_labels_seq)
		labels = self.label_compression(new_labels_seq)
		
		# seq1.extend(labels)
		# Replace old labels with new rather than extend
		seq1 = labels
		return seq1		


	def label_compression(self, labels):
		labels_compressed = [self.label_dict[l] for l in labels]
	
		return labels_compressed


	def label_hashing(self, seq):
		label_keys = self.label_dict.keys()
		last_num = len(label_keys) - 1
		
		for label in seq:
			if label not in label_keys:
				self.label_dict[label] = str(last_num + 1)
				last_num = last_num + 1
		return


	def label_count(self, labels, max_label):
		labels_int = [int(l) for l in labels]
		count_list = [0] * (max_label +1)

		for label in labels_int:
			count_list[label] += 1
	
		return count_list


	def graph_similiarity(self, label1, label2):
		similarity = np.dot(label1, label2)	
	
		return similarity


	def calculate_weisfeiler_lehman_graph(self, seq1, connections1, seq2, connections2, num_iterations=1):

		# Hash initial labels in both sequences into self.label_dict
		self.label_hashing(seq1)
		self.label_hashing(seq2)
		
		# Convert each element of seq1, seq2 to compressed labels (ints as strings)
		label_seq1 = self.label_compression(seq1)
		label_seq2 = self.label_compression(seq2)
		
		# Iterative WL color refinement 
		for n in range(num_iterations):
			label_seq1 = self.propagate_class_labels(label_seq1, connections1)
			label_seq2 = self.propagate_class_labels(label_seq2, connections2)


		# Count how many times each label occurs in each graph 
		max_val = max(max([int(l) for l in label_seq1]), max([int(l) for l in label_seq2]))
		count_list1 = self.label_count(label_seq1, max_val)
		count_list2 = self.label_count(label_seq2, max_val)
		
		# Compute dot product of the label-frequency vectors 
		similarity_raw = self.graph_similiarity(count_list1, count_list2)

		# Optionally, normalize these graph similarity scores
		norm1 = np.linalg.norm(count_list1)
		norm2 = np.linalg.norm(count_list2)
		similarity_cosine = similarity_raw / (norm1 * norm2 + 1e-9)

		return similarity_cosine

# %% [markdown]
# # RNAfold Local Implementation
# Define the RNAfold class and helper methods to run RNAfold with specified constraints and then to extract and create the graphs from its output needed to compute the WL graph similarity. This assumes that we are using a locally installed version of RNAfold.

# %%
def RNAfold(rnafold_cmd, fasta_file, constraint):
    
    fasta_file_preffix = fasta_file.rsplit('.', 1)[0]
    output_pdf = fasta_file_preffix + '_proteins.fa'
    log_file = fasta_file_preffix + '_RNAfold.log'
    rnafold_cmd += ' {input_fasta} --filename-full'
    if constraint == True: rnafold_cmd += " -C"     
    
    rnafold_cmd = rnafold_cmd.format(input_fasta=fasta_file)
    
    with open(log_file, 'w') as lf:
    	sp.call(rnafold_cmd.split(), stdout = lf)
    	
    os.remove(log_file)
        
    return

# %%
def create_fasta_constraints(seq, dms_seq, file_name, constraints = False, divide_by = 1):

	constraints = ""
	
	# Previous cutoff threshold was 0.04
	# Apply hard constraint with cutoff threshold of 0.06
	for dms in dms_seq:
		if dms/divide_by < 0.06:
			constraints += "."
		elif dms/divide_by >= 0.06:
			constraints += "x"

	rand_id = str(uuid.uuid1())

	file_ = open(file_name, "w")
	
	file_.write(">" + rand_id)
	file_.write("\n")
	file_.write(seq)
	if constraints: file_.write("\n")
	if constraints: file_.write(constraints)	
	file_.close()

	return constraints, file_name

# %%
def extract_graph(file_name):


	file_ = open(file_name)
	lines = file_.readlines()
	
	start_ind = lines.index("/pairs [\n")
	end_ind = start_ind + lines[start_ind:].index("] def\n")

	connected = lines[start_ind + 1:end_ind]
	connected = [[int(c[:-1].split(" ")[0][1:])-1, int(c[:-1].split(" ")[1][:-1])-1] for c in connected]
	file_.close()

	return connected

# %%
def create_graph(input_file, constraint):

	RNAfold("RNAfold", input_file, constraint)
	
	os.remove(input_file)
	current_files = glob.glob("./*.ps")
	connected = extract_graph(current_files[0])
	os.remove(current_files[0])

	return connected

# %% [markdown]
# # LSTM Training and Evaluation
# Define the train and evaluate method for our defined LSTM.

# %%
# Define training method 
def train_model(trainloader, net, criterion, optimizer, epoch, teacher_forcing_ratio = 0.25):

	torch.autograd.set_detect_anomaly(True)
	running_loss = 0.0
	net.zero_grad()
	
	
	for i, data in enumerate(trainloader):
		input_data, target_data = data
		loss = 0
		hidden = net.initHidden()
		optimizer.zero_grad()
		output, hidden = net(torch.IntTensor(input_data), hidden)

		# loss = pearson_loss(output.squeeze(), target_data[0], input_data)
		loss = criterion(output.squeeze(),target_data[0])
		
		
		loss.backward()
		optimizer.step()
		running_loss = running_loss + loss

	return net, running_loss/len(trainloader)

# %%
# Define evaluation method
def eval_model(dataloader, net, criterion, epoch, pearson =False):


	running_loss = 0
	input_data_list = []
	output_data_list = []
	target_data_list = []
	
	with torch.no_grad():
		for data in dataloader:
			input_data, target_data = data
			loss = 0
			hidden = net.initHidden()
			output, hidden = net(torch.IntTensor(input_data), hidden)
		
			if pearson == False:
				loss = criterion(output.squeeze(), target_data[0])
			else:
			
				loss = pearson_loss(output.squeeze(), target_data[0], input_data)
			
			
			running_loss = running_loss + loss
			
			input_data_list.append(input_data)
			output_data_list.append(output.squeeze())
			target_data_list.append(target_data[0])
	    
	return running_loss/len(dataloader), output_data_list, input_data_list, target_data_list

# %% [markdown]
# Run the main training and evaluation loop for the LSTM on the preprocessed DMS data. The outer loop iterates over all folds, while the inner loop iterates over all training epochs. At the end of training, we evaluate the model on the test data.
#
# We use the trained LSTM to predict DMS values of the correpsonding RNA sequences. These are then used to generate and pass constraints to RNAfold as one of the settings mentioned to combine both experimental DMS data with RNAfold's thermodynamic scoring model.
#
# We then run RNAfold on both settings with the model's DMS feature vectors and without, and then compute the WL graph similarity between them to see how the predicted DMS values from our trained LSTM affects RNAfold's predictions.

# %%
for enum, indices in enumerate(kfold.split( dataset.return_x(), list(range(len(dataset.return_y()))))):
    # Enumerate over every fold

    train_indices, test_val_ind = indices[0], indices[1]
    split2 = int(np.floor(0.5 * len(test_val_ind)))
    val_indices,test_indices = test_val_ind[split2:], test_val_ind[:split2]
    
    g = torch.Generator()
    g.manual_seed(0)

    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(val_indices)
    test_sampler = SubsetRandomSampler(test_indices)

    train_loader = DataLoader(dataset, batch_size=1, sampler = train_sampler, collate_fn=my_collate, generator=g)
    validation_loader = DataLoader(dataset, batch_size = 1, sampler = valid_sampler, collate_fn=my_collate, generator=g)
    test_loader = DataLoader(dataset, batch_size = 1, sampler = test_sampler, collate_fn=my_collate, generator=g)

    hidden_size = 50
    net = LSTM(dataset.num_words(),hidden_size, max_length=dataset.max_length)
    saved_net =  LSTM(dataset.num_words(),hidden_size, max_length=dataset.max_length)
    optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

    # Currently using only custom pearson loss 
    criterion = nn.L1Loss()
    best_validation = np.inf
    epoch_range = 10

    for epoch in range(0, epoch_range):
            
        net, running_loss = train_model(train_loader, net = net, criterion = criterion,  optimizer = optimizer, epoch = epoch)
        running_loss_val, output, input_data, target_data = eval_model(validation_loader, net, criterion = criterion, epoch = epoch)
        print(f'train-loss in epoch {epoch}: {running_loss}')

        if running_loss_val <= best_validation and epoch > int(epoch_range/2):
            best_validation = running_loss_val
            saved_net.load_state_dict(net.state_dict())
            
    
    print(f'best val-loss:{best_validation}')
    #### final test using pearson correlation #####
    print("##############################################################################################")
    
    
    running_loss, output, input_data, target_data_list = eval_model(test_loader, saved_net, criterion = criterion, epoch = epoch, pearson = True)
    
    print(f'pearson-correlation in fold {enum}: {running_loss}')
    
    file_name = "./test.fa"

    graph_similarity = []
    
    for en,dms_predicted in enumerate(output):
    
        seq = dataset.reconstruct_input(input_data[en])
        
        # Create constraints for the setting with DMS feature vector predicted from the LSTM and build its graph
        constraints, input_file = create_fasta_constraints(seq, dms_predicted, file_name, constraints = True, divide_by = scale_factor)
        first_connections = create_graph(input_file, constraint = True)
        
        # Create constraints for the setting without and build its graph
        constraints, input_file = create_fasta_constraints(seq, dms_predicted, file_name, constraints = False, divide_by = scale_factor)
        second_connections = create_graph(input_file, constraint = False)
        
        kernel = Weisfeiler_Lehman_Graph()

        # Compare both graphs using WL 
        graph_sim = kernel.calculate_weisfeiler_lehman_graph(seq, first_connections, seq, second_connections, num_iterations = 1)
        graph_similarity.append(graph_sim)

    kfold_loss.append(running_loss)
    graph_sim_loss.append(graph_similarity)
    
    
    print(f'graph similarity in fold {enum}: {np.mean(graph_similarity)}')
# Out:
# train-loss in epoch 0: 1.7065527439117432
# train-loss in epoch 1: 1.3966858386993408
# train-loss in epoch 2: 1.385648250579834
# train-loss in epoch 3: 1.3779101371765137
# train-loss in epoch 4: 1.3747235536575317
# train-loss in epoch 5: 1.3742960691452026
# train-loss in epoch 6: 1.3735946416854858
# train-loss in epoch 7: 1.3715449571609497
# train-loss in epoch 8: 1.3701952695846558
# train-loss in epoch 9: 1.3700186014175415
# best val-loss:1.2919033765792847
# ##############################################################################################
# pearson-correlation in fold 0: 0.6263292723894119
# graph similarity in fold 0: 0.9999999999970873
# train-loss in epoch 0: 1.6560981273651123
# train-loss in epoch 1: 1.3650643825531006
# train-loss in epoch 2: 1.3553040027618408
# train-loss in epoch 3: 1.3481696844100952
# train-loss in epoch 4: 1.343807339668274
# train-loss in epoch 5: 1.3416534662246704
# train-loss in epoch 6: 1.3388503789901733
# train-loss in epoch 7: 1.3396278619766235
# train-loss in epoch 8: 1.3384661674499512
# train-loss in epoch 9: 1.3374485969543457
# best val-loss:1.3970681428909302
# ##############################################################################################
# pearson-correlation in fold 1: 0.5900688728690148
# graph similarity in fold 1: 0.9999999999971892
# train-loss in epoch 0: 1.6980265378952026
# train-loss in epoch 1: 1.3953405618667603
# train-loss in epoch 2: 1.385807991027832
# train-loss in epoch 3: 1.3803045749664307
# train-loss in epoch 4: 1.3767138719558716
# train-loss in epoch 5: 1.374142050743103
# train-loss in epoch 6: 1.370904803276062
# train-loss in epoch 7: 1.3668348789215088
# train-loss in epoch 8: 1.3675161600112915
# train-loss in epoch 9: 1.3681206703186035
# best val-loss:1.3068526983261108
# ##############################################################################################
# pearson-correlation in fold 2: 0.5955814132094384
# graph similarity in fold 2: 0.9999999999971468
# train-loss in epoch 0: 1.6303519010543823
# train-loss in epoch 1: 1.3907111883163452
# train-loss in epoch 2: 1.3814936876296997
# train-loss in epoch 3: 1.3739182949066162
# train-loss in epoch 4: 1.367691993713379
# train-loss in epoch 5: 1.3652987480163574
# train-loss in epoch 6: 1.3627220392227173
# train-loss in epoch 7: 1.3636736869812012
# train-loss in epoch 8: 1.360532522201538
# train-loss in epoch 9: 1.3604388236999512
# best val-loss:1.3473944664001465
# ##############################################################################################
# pearson-correlation in fold 3: 0.625910864174366
# graph similarity in fold 3: 0.9999999999971996
# train-loss in epoch 0: 1.6895488500595093
# train-loss in epoch 1: 1.3983452320098877
# train-loss in epoch 2: 1.3928959369659424
# train-loss in epoch 3: 1.3866491317749023
# train-loss in epoch 4: 1.383671760559082
# train-loss in epoch 5: 1.3824172019958496
# train-loss in epoch 6: 1.3778274059295654
# train-loss in epoch 7: 1.3772838115692139
# train-loss in epoch 8: 1.3739559650421143
# train-loss in epoch 9: 1.368126630783081
# best val-loss:1.315805196762085
# ##############################################################################################
# pearson-correlation in fold 4: 0.600650106370449
# graph similarity in fold 4: 0.9999999999970807

# %% [markdown]
# We then compute and compare the pearson-correlation in each fold and the (normalized) WL graph similarity. The pearson correlation coefficient represents the accuracy of RNAfold predicted secondary structures, compared to their true structures in the data. The normalized graph similarity measures how similar the predictions from both settings (with LSTM predicted DMS scores and without) of RNAfold. We can use this to observe how much of a difference the LSTM predictions make to RNAfold's prediction accuracy, with scores close to 1 indicating identical predictions and thus no significant difference.

# %%
for num, auprc in enumerate(kfold_loss):
    print(f'pearson-correlation in fold {num}: {kfold_loss[num]}')
    print(f'Graph-similarity in fold {num}: {np.mean(graph_sim_loss[num])}')
# Out:
# pearson-correlation in fold 0: 0.6275616657733917
# Graph-similarity in fold 0: 391.45
# pearson-correlation in fold 1: 0.5887924933433533
# Graph-similarity in fold 1: 389.26
# pearson-correlation in fold 2: 0.5955320447683334
# Graph-similarity in fold 2: 402.32
# pearson-correlation in fold 3: 0.6232126426696777
# Graph-similarity in fold 3: 403.33
# pearson-correlation in fold 4: 0.5983535408973694
# Graph-similarity in fold 4: 378.08
# pearson-correlation in fold 5: 0.6263292723894119
# Graph-similarity in fold 5: 0.9999999999970873
# pearson-correlation in fold 6: 0.5900688728690148
# Graph-similarity in fold 6: 0.9999999999971892
# pearson-correlation in fold 7: 0.5955814132094384
# Graph-similarity in fold 7: 0.9999999999971468
# pearson-correlation in fold 8: 0.625910864174366
# Graph-similarity in fold 8: 0.9999999999971996
# pearson-correlation in fold 9: 0.600650106370449
# Graph-similarity in fold 9: 0.9999999999970807

# %%
print(f'Average Loss over all folds: {np.mean(kfold_loss)}')
print(f'Average Graph-similarity over all folds: {np.mean(graph_sim_loss)}')
# Out:
# Average Loss over all folds: 0.6071992916464806
# Average Graph-similarity over all folds: 196.94399999999857
